# %% [markdown]
# # 门控循环单元（GRU）--- 从0开始
#
# [上一节](bptt.md)中，我们介绍了循环神经网络中的梯度计算方法。我们发现，循环神经网络的隐含层变量梯度可能会出现衰减或爆炸。虽然[梯度裁剪](rnn-scratch.md)可以应对梯度爆炸，但无法解决梯度衰减的问题。因此，给定一个时间序列，例如文本序列，循环神经网络在实际中其实较难捕捉两个时刻距离较大的文本元素（字或词）之间的依赖关系。
#
# 门控循环神经网络（gated recurrent neural networks）的提出，是为了更好地捕捉时序数据中间隔较大的依赖关系。其中，门控循环单元（gated recurrent unit，简称GRU）是一种常用的门控循环神经网络。它由Cho、van Merrienboer、 Bahdanau和Bengio在2014年被提出。
#
#
# ## 门控循环单元
#
# 我们先介绍门控循环单元的构造。它比循环神经网络中的隐含层构造稍复杂一点。
#
# ### 重置门和更新门
#
# 门控循环单元的隐含状态只包含隐含层变量$\mathbf{H}$。假定隐含状态长度为$h$，给定时刻$t$的一个样本数为$n$特征向量维度为$x$的批量数据$\mathbf{X}_t \in \mathbb{R}^{n \times x}$和上一时刻隐含状态$\mathbf{H}_{t-1} \in \mathbb{R}^{n \times h}$，重置门（reset gate）$\mathbf{R}_t \in \mathbb{R}^{n \times h}$和更新门（update gate）$\mathbf{Z}_t \in \mathbb{R}^{n \times h}$的定义如下：
#
# $$\mathbf{R}_t = \sigma(\mathbf{X}_t \mathbf{W}_{xr} + \mathbf{H}_{t-1} \mathbf{W}_{hr} + \mathbf{b}_r)$$
#
# $$\mathbf{Z}_t = \sigma(\mathbf{X}_t \mathbf{W}_{xz} + \mathbf{H}_{t-1} \mathbf{W}_{hz} + \mathbf{b}_z)$$
#
# 其中的$\mathbf{W}_{xr}, \mathbf{W}_{xz} \in \mathbb{R}^{x \times h}$和$\mathbf{W}_{hr}, \mathbf{W}_{hz} \in \mathbb{R}^{h \times h}$是可学习的权重参数，$\mathbf{b}_r, \mathbf{b}_z \in \mathbb{R}^{1 \times h}$是可学习的偏移参数。函数$\sigma$自变量中的三项相加使用了[广播](../chapter_crashcourse/ndarray.md)。
#
# 需要注意的是，重置门和更新门使用了值域为$[0, 1]$的函数$\sigma(x) = 1/(1+\text{exp}(-x))$。因此，重置门$\mathbf{R}_t$和更新门$\mathbf{Z}_t$中每个元素的值域都是$[0, 1]$。
#
#
# ### 候选隐含状态
#
# 我们可以通过元素值域在$[0, 1]$的更新门和重置门来控制隐含状态中信息的流动：这通常可以应用按元素乘法符$\odot$。门控循环单元中的候选隐含状态$\tilde{\mathbf{H}}_t \in \mathbb{R}^{n \times h}$使用了值域在$[-1, 1]$的双曲正切函数tanh做激活函数：
#
# $$\tilde{\mathbf{H}}_t = \text{tanh}(\mathbf{X}_t \mathbf{W}_{xh} + \mathbf{R}_t \odot \mathbf{H}_{t-1} \mathbf{W}_{hh} + \mathbf{b}_h)$$
#
# 其中的$\mathbf{W}_{xh} \in \mathbb{R}^{x \times h}$和$\mathbf{W}_{hh} \in \mathbb{R}^{h \times h}$是可学习的权重参数，$\mathbf{b}_h \in \mathbb{R}^{1 \times h}$是可学习的偏移参数。
#
# 需要注意的是，候选隐含状态使用了重置门来控制包含过去时刻信息的上一个隐含状态的流入。如果重置门近似0，上一个隐含状态将被丢弃。因此，重置门提供了丢弃与未来无关的过去隐含状态的机制。
#
#
# ### 隐含状态
#
# 隐含状态$\mathbf{H}_t \in \mathbb{R}^{n \times h}$的计算使用更新门$\mathbf{Z}_t$来对上一时刻的隐含状态$\mathbf{H}_{t-1}$和当前时刻的候选隐含状态$\tilde{\mathbf{H}}_t$做组合，公式如下：
#
# $$\mathbf{H}_t = \mathbf{Z}_t \odot \mathbf{H}_{t-1}  + (1 - \mathbf{Z}_t) \odot \tilde{\mathbf{H}}_t$$
#
# 需要注意的是，更新门可以控制过去的隐含状态在当前时刻的重要性。如果更新门一直近似1，过去的隐含状态将一直通过时间保存并传递至当前时刻。这个设计可以应对循环神经网络中的梯度衰减问题，并更好地捕捉时序数据中间隔较大的依赖关系。
#
# 我们对门控循环单元的设计稍作总结：
#
# * 重置门有助于捕捉时序数据中短期的依赖关系。
# * 更新门有助于捕捉时序数据中长期的依赖关系。
#
#
# 输出层的设计可参照[循环神经网络](rnn-scratch.md)中的描述。
#
#
# ## 实验
#
#
# 为了实现并展示门控循环单元，我们依然使用周杰伦歌词数据集来训练模型作词。这里除门控循环单元以外的实现已在[循环神经网络](rnn-scratch.md)中介绍。
#
#
# ### 数据处理
#
# 我们先读取并对数据集做简单处理。

# %%
import zipfile
with zipfile.ZipFile('../data/jaychou_lyrics.txt.zip', 'r') as zin:
    zin.extractall('../data/')

with open('../data/jaychou_lyrics.txt') as f:
    corpus_chars = f.read()

corpus_chars = corpus_chars.replace('\n', ' ').replace('\r', ' ')
corpus_chars = corpus_chars[0:20000]

idx_to_char = list(set(corpus_chars))
char_to_idx = dict([(char, i) for i, char in enumerate(idx_to_char)])
corpus_indices = [char_to_idx[char] for char in corpus_chars]

vocab_size = len(char_to_idx)
print('vocab size:', vocab_size)
# Out:
# ('vocab size:', 88)

# %% [markdown]
# 我们使用onehot来将字符索引表示成向量。

# %%
def get_inputs(data):
    return [nd.one_hot(X, vocab_size) for X in data.T]

# %% [markdown]
# ### 初始化模型参数
#
# 以下部分对模型参数进行初始化。参数`hidden_dim`定义了隐含状态的长度。

# %%
import mxnet as mx

# 尝试使用GPU
import sys
sys.path.append('..')
from mxnet import nd
import utils
ctx = utils.try_gpu()
print('Will use', ctx)

input_dim = vocab_size
# 隐含状态长度
hidden_dim = 256
output_dim = vocab_size
std = .01

def get_params():
    # 隐含层
    W_xz = nd.random_normal(scale=std, shape=(input_dim, hidden_dim), ctx=ctx)
    W_hz = nd.random_normal(scale=std, shape=(hidden_dim, hidden_dim), ctx=ctx)
    b_z = nd.zeros(hidden_dim, ctx=ctx)
    
    W_xr = nd.random_normal(scale=std, shape=(input_dim, hidden_dim), ctx=ctx)
    W_hr = nd.random_normal(scale=std, shape=(hidden_dim, hidden_dim), ctx=ctx)
    b_r = nd.zeros(hidden_dim, ctx=ctx)

    W_xh = nd.random_normal(scale=std, shape=(input_dim, hidden_dim), ctx=ctx)
    W_hh = nd.random_normal(scale=std, shape=(hidden_dim, hidden_dim), ctx=ctx)
    b_h = nd.zeros(hidden_dim, ctx=ctx)

    # 输出层
    W_hy = nd.random_normal(scale=std, shape=(hidden_dim, output_dim), ctx=ctx)
    b_y = nd.zeros(output_dim, ctx=ctx)

    params = [W_xz, W_hz, b_z, W_xr, W_hr, b_r, W_xh, W_hh, b_h, W_hy, b_y]
    for param in params:
        param.attach_grad()
    return params
# Out:
# ('Will use', cpu(0))

# %% [markdown]
# ## 定义模型
#
# 我们将前面的模型公式翻译成代码。

# %%
def gru_rnn(inputs, H, *params):
    # inputs: num_steps 个尺寸为 batch_size * vocab_size 矩阵
    # H: 尺寸为 batch_size * hidden_dim 矩阵
    # outputs: num_steps 个尺寸为 batch_size * vocab_size 矩阵
    W_xz, W_hz, b_z, W_xr, W_hr, b_r, W_xh, W_hh, b_h, W_hy, b_y = params
    outputs = []
    for X in inputs:        
        Z = nd.sigmoid(nd.dot(X, W_xz) + nd.dot(H, W_hz) + b_z)
        R = nd.sigmoid(nd.dot(X, W_xr) + nd.dot(H, W_hr) + b_r)
        H_tilda = nd.tanh(nd.dot(X, W_xh) + R * nd.dot(H, W_hh) + b_h)
        H = Z * H + (1 - Z) * H_tilda
        Y = nd.dot(H, W_hy) + b_y
        outputs.append(Y)
    return (outputs, H)

# %% [markdown]
# ### 训练模型
#
# 下面我们开始训练模型。我们假定谱写歌词的前缀分别为“分开”、“不分开”和“战争中部队”。这里采用的是相邻批量采样实验门控循环单元谱写歌词。

# %%
seq1 = '分开'
seq2 = '不分开'
seq3 = '战争中部队'
seqs = [seq1, seq2, seq3]

utils.train_and_predict_rnn(rnn=gru_rnn, is_random_iter=False, epochs=200,
                            num_steps=35, hidden_dim=hidden_dim, 
                            learning_rate=0.2, clipping_norm=5,
                            batch_size=32, pred_period=20, pred_len=100,
                            seqs=seqs, get_params=get_params,
                            get_inputs=get_inputs, ctx=ctx,
                            corpus_indices=corpus_indices,
                            idx_to_char=idx_to_char, char_to_idx=char_to_idx)
# Out:
# Epoch 20. Training perplexity 9.003881
# (' - ', '\xe5\x88\x86\xe5\xbc\x80\xe5\x8f\xaf\xe7\x88\xb1\xe5\xa5\xb3\xe4\xba\xba ')
# (' - ', '')
# (' - ', '')
# ()
# Epoch 40. Training perplexity 3.302059
# (' - ', '\xe5\x88\x86\xe5\xbc\x80\xe5\xa7\x8b \xe6\x88\x91\xe6\x83\xb3\xe5\xb0\xb1\xe8\xbf\x99\xe6\xa0\xb7\xe7\x89\xb5\xe7\x9d\x80\xe4\xbd\xa0\xe7\x9a\x84\xe8\xaf\x9d\xe6\x88\x91\xe9\xbb\x98\xe9\xbb\x98\xe7\x89\x8b\xe7\x9d\x80\xe6\xad\x8b \xe5\x8d\x8f\xe5\x9c\xb0\xe5\xae\x89\xe6\x96\x91\xe9\xb8\xa0\xe6\x8a\x82\xe4\xba\x86\xe5\xae\x83\xe6\xaf\xae\xe7\x9a\x84\xe8\xaf\x9d\xe6\xb2\xa1 \xe6\x9c\x89\xe6\x98\xaf\xe6\x88\x91\xe5\xa6')
# (' - ', '\xe4\xb8\x8d\xe5\x88\x86\xe5\xbc\x80\xe4\xbd\xa0 \xe6\x88\x91\xe6\x83\xb3\xe5\xb8\xa6\xe4\xbd\xa0 \xe5\x88\xab\xe6\x88\x91\xe6\x83\xb3\xe8\xa6\x81\xe4\xbd\xa0 \xe9\x99\x8c\xe4\xb8\x8d\xe6\x83\xb3\xe5\xa4\xa9 \xe4\xbb\x96\xe5\x9c\xa8\xe6\x96\x97\xe5\x8f\x97\xe6\x88\x91 \xe6\xb3\xaa\xe4\xb8\x8d\xe6\x83\xb3\xe8\x91\x97\xe6\xaf\xb4\xe9\xbb\x98\xe9\xbb\x98\xe9\xbb\x98\xe9\xbb\x98\xe9\xad\xa2\xe7\x9a\x84\xe6\x97\xa9\xe6\x96\xb9')
# (' - ', '\xe6\x88\x98\xe4\xba\x89\xe4\xb8\xad\xe9\x83\xa8\xe9\x98\x9f\xe5\x90\xa6 \xe4\xb8\x8d\xe8\xaf\xa5\xe5\xb0\xb1\xe8\xbf\x99\xe6\xa0\xb7\xe6\x89\x8d\xe7\x9d\xa5\xe4\xb8\x8d\xe7\x9f\xa5\xe4\xb8\x8d\xe8\xa7\x89 \xe6\x88\x91\xe8\xaf\xb4\xe5\xba\x97\xe5\x9c\xa8\xe7\x9d\xa1\xe7\x9d\x80\xe6\x88\x91 \xe6\xb3\xe4\xe4\xbb\x80\xe4\xbd\xa0\xe7\x9a\x84\xe5\x8f\xaf\xe7\x88\xb1\xe5\xa5\xb3\xe4\xba\xba \xe6\xbc\x82\xe4\xba\xae\xe7\x9a\x84\xe8\xae\xa9\xe6\x88\x91\xe7')
# ()
# Epoch 60. Training perplexity 1.441036
# (' - ', '\xe5\x88\x86\xe5\xbc\x80\xe4\xb9\x88\xe9\x9d\xa2\xe4\xb8\x8d\xe6\x83\xb3 \xe4\xbd\xa0\xe8\xaf\xb4 \xe8\xbd\xa6\xe8\xbd\xbd\xe9\xbb\x98\xe4\xbb\x91\xe9\xa6\xbb\xe5\x91\xbc\xe9\xa3\x99\xe4\xb8\x8d\xe6\x87\xbe \xe6\xbc\x82\xe6\x89\x96 \xe6\x88\x91\xe6\x83\xb3\xe6\xb0\xbf\xe8\xbf\x99\xe6\xa0\xb7 \xe4\xbd\xe5\xa4\x9a\xe9\xa3\x8e \xe4\xb8\x8d\xe6\x83\xb3\xe5\xa4\xaa\xe5\xa4\x9a \xe6\x88\x91\xe6\x83\xb3\xe4\xb8')
# (' - ', '\xe4\xb8\x8d\xe5\x88\x86\xe5\xbc\x80\xe5\xa1\x99\xe9\x87\x8c \xe4\xbd\xa0\xe6\x98\xaf\xe4\xbd\xa0 \xe4\xb8\x8d\xe7\xa6\x81\xe5\x8d\xb0\xe8\xbf\x87\xe6\xa0\xb7\xe7\x89\xb5\xe7\x9d\x80\xe4\xbd\xa0\xe7\x9a\x84\xe6\x89\x8b\xe4\xb8\x8d\xe6\x94\xbe\xe5\xbc\x80 \xe7\x88\xb1\xe8\x83\xbd\xe4\xb8\x8d\xe8\x83\xbd\xe5\xa4\x9f\xe6\xb0\xb8\xe8\xbf\x9c\xe5\x8d\x95\xe7\xba\xaf\xe6\xb2\xa1\xe6\x9c\x89\xe6\x82\xb2\xe5\x93\x80 \xe6\x88\x91 ')
# (' - ', '\xe6\x88\x98\xe4\xba\x89\xe4\xb8\xad\xe9\x83\xa8\xe9\x98\x9f\xe6\x98\x85\xe4\xb8\x80\xe5\xae\x9a\xe6\x84\x9f\xe6\x97\xb4 \xe9\x83\xbd\xe6\x98\xaf\xe4\xb9\x8b\xe9\x98\xaf\xe6\x88\x91 \xe4\xb8\x80\xe6\x83\xb3\xe5\xa4\xa9\xe5\xbf\x86 \xe6\xb0\xb7\xe8\xbf\x9c\xe8\x8b\x82\xe9\xa3\x8e\xe9\xbb\x98 \xe8\xaf\xb4\xe8\xbf\x98\xe8\xaf\xb4 \xe4\xbd\xa0 \xe7\x88\xb1\xe6\x83\x85\xe6\x9d\xa2\xe7\x9a\x84\xe5\xa4\xaa\xe5\xbf\xab\xe5\xb0\xb1\xe5\x83\x8f\xe9\xbe')
# ()
# Epoch 80. Training perplexity 1.103287
# (' - ', '\xe5\x88\x86\xe5\xbc\x80\xe5\x88\xb0 \xe5\x88\xb0\xe5\xae\x83\xe4\xb8\x80\xe4\xb9\x88\xe9\x83\xbd\xe6\x88\x90  \xe6\x98\x9f\xe6\x88\x91\xe5\xb7\xb2\xe6\x97\xa0\xe5\xa4\xa7 \xe8\x99\xaa\xe8\xae\xa9\xe6\x88\x91\xe5\xbc\x80\xe5\xa7\x8b\xe4\xb9\xa1\xe7\x9b\xb8\xe4\xbf\xa1\xe5\x91\xbd\xe8\xbf\x90 \xe6\x84\x9f\xe8\xb0\xa2\xe5\x9c\xb0\xe5\xbf\x83\xe5\xbc\x95\xe5\x8a\x9b \xe8\xae\xa9\xe6\x88\x91\xe7\xa2\xb0\xe5\x88')
# (' - ', '\xe4\xb8\x8d\xe5\x88\x86\xe5\xbc\x80\xe5\xa1\xb4\xe9\x97\xa0 \xe6\x88\x91\xe6\x83\xb3\xe5\xb0\xb1\xe8\xbf\x99\xe6\xa0\xb7\xe7\x89\xb5\xe7\x9d\x80\xe4\xbd\xa0\xe7\x9a\x84\xe6\x89\x8b\xe4\xb8\x8d\xe6\x94\xbe\xe5\xbc\x80 \xe7\x88\xb1\xe8\x83\xbd\xe4\xb8\x8d\xe8\x83\xbd\xe5\xa4\x9f\xe6\xb0\xb8\xe8\xbf\x9c\xe5\x8d\x95\xe7\xba\xaf\xe6\xb2\xa1\xe6\x9c\x89\xe6\x82\xb2\xe5\x93\x80 \xe6\x88\x91 \xe6\x83\xb3\xe5\xb8\xa6\xe4\xbd\xa0\xe9')
# (' - ', '\xe6\x88\x98\xe4\xba\x89\xe4\xb8\xad\xe9\x83\xa8\xe9\x98\x9f\xe5\x8f\x85\xe8\xbf\xb0 \xe8\xae\xa9\xe5\xae\x83\xe5\xbf\x83\xe5\xb8\x8c\xe5\xbf\x86\xe6\xaf\xb4\xe4\xba\x86\xe5\x90\x8e \xe8\xbf\x98\xe6\x98\xaf\xe8\x91\x97\xe8\xb5\xb0 \xe8\xbf\x99\xe9\x87\x8c\xe4\xbb\x80\xe4\xb9\x88\xe5\xa5\x87\xe6\x80\xaa\xe7\x9a\x84\xe4\xba\x8b\xe9\x83\xbd\xe6\x9c\x89 \xe5\x8c\x85\xe6\x8b\xac\xe5\x83\x8f\xe7\x8c\xab\xe7\x9a\x84\xe7\x8b\x97 \xe5\x8d\xb0\xe5\x9c\xb0')
# ()
# Epoch 100. Training perplexity 1.046170
# (' - ', '\xe5\x88\x86\xe5\xbc\x80\xe5\xae\xb4\xe7\x9a\x84\xe7\x94\xa8\xe8\x9b\x9c\xe6\xb2\xa1\xe6\x9c\x89\xe7\xe7\x84\xe5\x9f\xac\xe5\xaf\xb9 \xe8\xbe\x8e\xe4\xb8\x88\xe5\xbe\x9d\xe6\x88\xb8\xe7\x9a\x84\xe8\xbf\xbf\xe8\x86\x80 \xe4\xbd\xa0 \xe9\x99\x93\xe4\xbd\xa0 \xe4\xb8\x8d\xe7\x95\xa1 \xe8\xbf\x98\xe6\x98\xaf\xe5\x90\xa6 \xe5\x86\x9e\xe5\xae\x9a\xe4\xb9\xad\xe4\xb8\x8d\xe5\xae\x9a \xe5\x8d\xb0\xe5\x88\x86\xe6')
# (' - ', '\xe4\xb8\x8d\xe5\x88\x86\xe5\xbc\x80\x9a\x9a\xb4\x9a\xb4\xbb\x97\xe7\x9b\x98 \xe6\x98\xaf\xe7\x88\x91\xe7\x9a\x84\xe5\xa4\xaf\xe5\xbf\x86\xe5\xa1\x95 \xe5\x9d\x8f\xe4\xb8\x8a\xe4\xba\x86\xe5\x90\x83\xe7\x8e\x9f \xe4\xb8\x8d\xe8\xa6\x81\xe5\xb0\xb1\xe5\x8f\xaa\xe7\x9a\xb1\xe5\xa5\xb3\xe6\xba\xbf\xe8\xb5\xb0\xe8\x80\x83 \xe6\x88\x91\xe4\xb8\x8d\xe8\xa6\x81\xe5\x86\x8d\xe6\x83\xb3 \xe6\x88\x91\xe4\xb8\x8d\xe8\xa6\x81\xe5\x86')
# (' - ', '\xe6\x88\x98\xe4\xba\x89\xe4\xb8\xad\xe9\x83\xa8\xe9\x98\x9f\xe5\x90\x85\xe5\x88\xb0 \xe8\xbf\x99\xe6\xa0\xb7\xe7\x89\xb5\xe7\x9d\x80\xe4\xbd\xa0\xe7\x9a\x84\xe6\x89\x8b\xe4\xb8\x8d\xe6\x94\xbe\xe5\xbc\x80 \xe7\x88\xb1\xe8\x83\xbd\xe4\xb8\x8d\xe8\x83\xbd\xe5\xa4\x9f\xe6\xb0\xb8\xe8\xbf\x9c\xe5\x8d\x95\xe7\xba\xaf\xe6\xb2\xa1\xe6\x9c\x89\xe6\x82\xb2\xe5\x93\x80 \xe6\x88\x91 \xe6\x83\xb3\xe5\xb8\xa6\xe4\xbd\xa0\xe9\xaa\x91\xe5\x8d\x95\xe8\xbd\xa6 ')
# ()
# Epoch 120. Training perplexity 1.034738
# (' - ', '\xe5\x88\x86\xe5\xbc\x80\xe5\xae\xb4\xe7\x9a\x84\xe7\x94\x9c\xe8\x9c\x9c \xe6\x88\x91\xe7\xbb\x99\xe4\xbd\xa0\xe7\x9a\x84\xe7\x88\xb1\xe5\x86\x99\xe5\x9c\xa8\xe8\xa5\xbf\xe5\x85\x83\xe5\x89\x8d \xe6\xb7\xb1\xe5\x9f\x8b\xe5\x9c\xa8\xe7\xbe\x8e\xe7\xb4\xa2\xe4\xb8\x8d\xe8\xbe\xbe\xe7\xb1\xb3\xe4\xba\xa7\xe5\xb9\xb3\xe9\x8e\x9f \xe5\x8d\xb0\xe5\xb9\x88\xe5\x86\x8d\xe8\xa7\x83\xe5\xb1\x8a\xe6\x96\xbc\xa0\xbd\xbd \xe4')
# (' - ', '\xe4\xb8\x8d\xe5\x88\x86\xe5\xbc\x80 \xe7\x9c\xba\xe6\x98\x9f\xe6\x98\xaf \xe4\xb8\x80\xe7\xa2\xb4\xe8\xae\xa9\xe6\x88\x91\xe6\x88\x91\xe4\xb8\x8d \xe6\x88\x91\xe4\xb8\x8d\xe8\xa6\x81\xe5\x86\x8d\xe6\x83\xb3\xe4\xbd\xa0 \xe4\xb8\x8d\xe7\x9f\xa5\xe4\xb8\x8d\xe8\xa7\x89 \xe4\xbd\xa0\xe5\xb7\xb2\xe7\xbb\x8f\xe7\xa6\xbb\xe5\xbc\x80\xe6\x88\x91 \xe4\xb8\x8d\xe7\x9f\xa5\xe4\xb8\x8d\xe8\xa7\x89 \xe6\x88\x91\xe8\xb7\x9f\xe4')
# (' - ', '\xe6\x88\x98\xe4\xba\x89\xe4\xb8\xad\xe9\x83\xa8\xe9\x98\x9f\xe5\x90\x85\xe5\x88\xb0\xe4\xbd\x9c\xe5\x88\xab\xe7\x88\xb1\xe4\xbd\xa0\xe7\x9a\x84\xe6\x97\xb6\xe7\xa9\xba \xe5\x81\x9c\xe6\xa0\xbc\xe5\x86\x85\xe5\xae\xb9\xe4\xb8\x8d\xe5\xbf\xa0 \xe6\x89\x80\xe6\x9c\x89\xe5\x9b\x9e\xe5\xbf\x86\xe5\xaf\xb9\xe7\x9d\x80\xe6\x88\x91\xe8\xbf\x9b\xe6\x94\xbb...... \xe5\x8f\xa4\xe5\xb7\xb4\xe6\xaf\x94\xe4\xbc\xa6\xe7\x8e\x8b\xe9\xa2\x81\xe5\xb8')
# ()
# Epoch 140. Training perplexity 1.029011
# (' - ', '\xe5\x88\x86\xe5\xbc\x80\xe5\x8f\xaa\xe7\xa5\x8f\xe4\xba\xba \xe6\xbc\x82\xe6\x9f\xb3\xe5\xa4\x84\xe5\x9c\xba\xe5\xb0\x8f \xe5\xb0\x8f\xe5\xa6\x81\xe5\xb8\xb8\xe5\xa3\x9d \xe7\x94\xa0\xe6\x88\x91 \xe5\x88\xab\xe6\x80\xaa\xe6\x88\x91 \xe8\xaf\xb4\xe4\xbd\xa0\xe6\x80\x8e\xe4\xb9\x88\xe9\x9d\xa2\xe5\xaf\xb9\xe6\x88\x91 \xe7\x94\xa9\xe5\xbc\x80\xe7\x90\x83\xe6\x88\x91\xe6\xbb\xa1\xe8\x85\x94\xe7\x9a\x84\xe6\x80')
# (' - ', '\xe4\xb8\x8d\xe5\x88\x86\xe5\xbc\x80\x9a\x9a\x84\xe6\x99\xa3\xe7\xa9\xb5 \xe6\x9c\x89\xe4\xb8\x8d\xe6\x87\x82\xe7\xaf\xae\xe7\x90\x83 \xe6\x9c\x89\xe7\xa7\x8d\xe4\xb8\x8d\xe8\xa6\x81\xe8\xb5\xb0 \xe4\xb8\x89\xe5\xaf\xb9\xe4\xb8\x89\xe6\x96\x97\xe7\x89\x9b \xe6\x9c\x89\xe4\xbb\x80\xe4\xb9\x88\xe4\xb8\x8d\xe5\xa6\xa5 \xe6\x9c\x89\xe8\xaf\x9d\xe5\xb0\xb1\xe7\x9b\xb4\xe8\xaf\xb4 \xe5\x88\xab\xe7\xaa\x9d\xe5\x9c\xa8\xe8\xa7')
# (' - ', '\xe6\x88\x98\xe4\xba\x89\xe4\xb8\xad\xe9\x83\xa8\xe9\x98\x9f\xe7\x9a\x84\xe5\xbe\x8e\xe5\xb0\x86\xe8\xae\xb0 \xe8\xbf\x99\xe6\xa0\xb7\xe7\xba\xaf\xe8\x9d\x80\xe6\x95\x85\xe6\xb2\xa1\xe6\x9c\x89 \xe6\x88\x91\xe9\xa9\xac\xe5\x84\xbf\xe6\x9c\x89\xe4\xba\x9b\xe7\x98\xa6 \xe4\xb8\x96\xe4\xba\x8b\xe7\x9c\x8b\xe9\x80\x8f \xe6\xb1\x9f\xe6\xb9\x96\xe4\xb8\x8a\xe6\xbd\xae\xe8\xb5\xb7\xe6\xbd\xae\xe8\x90\xbd \xe4\xbb\x80\xe4\xb9\x88\xe6\x81\xa9\xe6\x80\xa8')
# ()
# Epoch 160. Training perplexity 1.027561
# (' - ', '\xe5\x88\x86\xe5\xbc\x80\xe5\x8f\xaa\xe7\xa5\x8f\xe5\xa5\xbd\xe6\x80\xaa\xe6\x87\x8b \xe6\x88\x91\xe6\x83\xb3\xe5\xb0\xb1\xe8\xbf\x99\xe6\xa0\xb7\xe7\x89\xb5\xe7\x9d\x80\xe4\xbd\xa0\xe7\x9a\x84\xe6\x89\x8b\xe4\xb8\x8d\xe6\x94\xbe\xe5\xbc\x80 \xe7\x88\xb1\xe8\x83\xbd\xe4\xb8\x8d\xe8\x83\xbd\xe5\xa4\x9f\xe6\xb0\xb8\xe8\xbf\x9c\xe5\x8d\x95\xe7\xba\xaf\xe6\xb2\xa1\xe6\x9c\x89\xe6\x82\xb2\xe5\x93\x80 \xe6\x88\x91 \xe6')
# (' - ', '\xe4\xb8\x8d\xe5\x88\x86\xe5\xbc\x80 \xe7\x9d\x80\xe5\x8d\xa8\xe5\x8f\xa4\xe9\xa3\x9e\xe9\x98\xbf\xe6\x98\xaf\xe5\x8f\xa4\xe5\xad\xbb\xe6\x98\xaf\xe5\x8f\xa7\xe6\x96\xb9\xe9\xb8\x85\xe5\x83\xb3\xe8\xa6\xbb\xe5\xb1\x9f \xe7\x8c\xb1\xe8\xbf\x99\xe4\xba\x86 \xe6\x88\x91\xe6\x83\xb3\xe5\xa4\xa7\xe5\xa3\xb0\xe5\xae\xa3\xe5\xb8\x83 \xe5\xaf\xb9\xe4\xbd\xa0\xe4\xbe\x9d\xe4\xbe\x9d\xe4\xb8\x8d\xe8\x88\x8d \xe8\xbf\x9e\xe9\x9a\x94')
# (' - ', '\xe6\x88\x98\xe4\xba\x89\xe4\xb8\xad\xe9\x83\xa8\xe9\x98\x9f\xe5\x90\x85 \xe5\x90\x8e\xe5\xae\x9e\xe6\x88\x91\xe7\x9a\x84\xe6\x84\xbf\xe6\x9c\x9b\xe5\xb0\xb1\xe6\x80\x8e\xe4\xb9\x88\xe5\xb0\x8f \xe5\xb0\xb1\xe6\x80\x8e\xe4\xb9\x88\xe6\xaf\x8f\xe5\xa4\xa9\xe7\xa5\x88\xe7\xa5\xb7\xe6\x88\x91\xe7\x9a\x84\xe5\xbf\x83\xe8\xb7\xb3\xe4\xbd\xa0\xe7\x9f\xa5\xe9\x81\x93  \xe6\x9d\xb5\xe5\x9c\xa8\xe4\xbc\x8a\xe6\x96\xaf\xe5\x9d\xa6\xe5\xa0\xa1 \xe5\x8d\xb4')
# ()
# Epoch 180. Training perplexity 1.025034
# (' - ', '\xe5\x88\x86\xe5\xbc\x80\xe5\x83\x8f\xe7\xa5\x9c\xe7\x9b\x9c \xe8\xbf\x98\xe6\x98\xaf\xe7\xa5\x9e\xe6\x98\xaf\xe8\xb0\x81\xe5\x83\x8f\xe5\xbe\x9d\xe7\x9d\x80\xe5\xbf\x83\xe5\xa1\xa1\xe7\x9d\x80\xe5\x8f\x97 \xe6\x88\x91\xe7\x89\x8d\xe4\xb8\x8d\xe7\x9d\x80 \xe5\x90\x8e\xe8\xbf\x90\xe6\x88\x91\xe8\xa2\xab\xe5\xa4\x96\xe9\x9a\x84\xe9\xa3\x99 \xe5\x9c\xa8\xe5\xb0\x8f\xe6\x9d\x91\xe5\xa4\x96\xe7\x9a\x84\xe6\xba\xaa\xe8')
# (' - ', '\xe4\xb8\x8d\xe5\x88\x86\xe5\xbc\x80\x9a\x9a\x84\xe9\x99\xa8\xe8\x91\x97\xe9\xa3\x8e \xe8\xbf\x99\xe6\xa0\xb7\xe6\x8b\x85\xe5\x92\x8c \xe4\xbd\xa0\xe6\x83\xb3\xe6\x88\x91\xe5\x88\xb0\xe6\x83\xb3\xe4\xba\x86 \xe4\xb8\x8d\xe4\xb8\x8d\xe4\xbc\x91 \xe8\xaf\xa5\xe8\x90\xbd \xe6\x88\x91\xe6\x83\xb3\xe5\xb8\xa6\xe4\xbd\xa0 \xe5\x9b\x9e\xe6\x88\x91\xe7\x9a\x84\xe5\xa4\x96\xe5\xa9\x86\xe5\xae\xb6 \xe4\xb8\x80\xe8\xb5\xb7\xe7')
# (' - ', '\xe6\x88\x98\xe4\xba\x89\xe4\xb8\xad\xe9\x83\xa8\xe9\x98\x9f\xe7\x9a\x84\xe5\xbd\xaf\xe7\x8b\xbc\xe6\xb2\xa1\xe6\x9c\x89\xe6\xb2\xa1\xe6\x9c\x89 \xe6\x88\x91\xe9\xa9\xac\xe5\x84\xbf\xe6\x9c\x89\xe4\xba\x9b\xe7\x98\xa6 \xe5\xa4\xa9\xe6\xb6\xaf\xe5\xb0\xbd\xe5\xa4\xb4 \xe6\xbb\xa1\xe8\x84\xb8\xe9\xa3\x8e\xe9\x9c\x9c\xe8\x90\xbd\xe5\xaf\x9e \xe8\xbf\x91\xe4\xb9\xa1\xe6\x83\x85\xe6\x80\xaf\xe7\x9a\x84\xe6\x88\x91 \xe7\x9b\xb8\xe6\x80\x9d\xe5\xaf\x84')
# ()
# Epoch 200. Training perplexity 1.023739
# (' - ', '\xe5\x88\x86\xe5\xbc\x80\xe5\xae\x99\xe5\x8e\xbb\xe5\xa5\xb3\xe4\xbd\xa0\xe7\x88\xb1\xe6\x88\x91\xe6\x9d\xa5\xe5\x85\xb6\xe5\x8f\x91\xe7\x8e\xb0 \xe6\x88\x91\xe5\x8d\xb4\xe5\x9c\xa8\xe5\x81\xb0 \xe4\xb8\x89\xe5\x8d\x83\xe7\xa5\x9f\xe7\x9b\x98\xe4\xb8\x80\xe5\xa4\x9a\x84\xbb\x99\xe5\xa4\x9f \xe7\xbb\x84\xe4\xba\x95\xe7\x9a\x84\xe8\xae\xa9\xe6\x88\x91\xe6\x84\x9f\xe5\x8a\xa8\xe7\x9a\x84\xe5\x8f\xaf\xe7\x88\xb1\xe5\xa5')
# (' - ', '\xe4\xb8\x8d\xe5\x88\x86\xe5\xbc\x80\x9a\x9a\xb4\xe7\x9a\x84\xe6\xa3\x8e\xe5\x90\xac \xe5\x90\x8e\xe5\xad\x90\xe8\xbd\xb7\xe5\xbb\x8a \xe4\xb8\x8d\xe6\x83\xb3\xe5\xa4\xaa\xe5\xa4\x9a \xe6\x88\x91\xe6\x83\xb3\xe4\xb8\x80\xe5\xae\x9a\xe6\x98\xaf\xe6\x88\x91\xe5\x90\xac\xe9\x94\x99\xe5\xbc\x84\xe9\x94\x99\xe6\x90\x9e\xe9\x94\x99 \xe6\x8b\x9c\xe6\x89\x98 \xe6\x88\x91\xe6\x83\xb3\xe6\x98\xaf\xe4\xbd\xa0\xe7\x9a\x84\xe8\x84\x91')
# (' - ', '\xe6\x88\x98\xe4\xba\x89\xe4\xb8\xad\xe9\x83\xa8\xe9\x98\x9f\xe5\x90\x83 \xe7\xa6\x99\xe6\x84\xa2\xe8\xb0\x81 \xe4\xbb\x8e\xe7\x89\x8b\xe4\xba\x86\xe6\x88\x91 \xe8\xaf\xb4\xe4\xbd\xa0\xe8\xaf\xb4 \xe5\x88\x86\xe6\x95\xb0\xe6\x80\x8e\xe4\xb9\x88\xe5\x81\x9c\xe7\x95\x99 \xe4\xb8\x80\xe7\x9b\xb4\xe5\x9c\xa8\xe5\x81\x9c\xe7\x95\x99 \xe8\xb0\x81\xe8\xae\xa9\xe5\xae\x83\xe5\x81\x9c\xe7\x95\x99\xe7\x9a\x84 \xe4\xb8\xba\xe4\xbb\x80\xe4\xb9\x88\xe6')
# ()

# %% [markdown]
# 可以看到一开始学到简单的字符，然后简单的词，接着是复杂点的词，然后看上去似乎像个句子了。
#
# ## 结论
#
# * 门控循环单元的提出是为了更好地捕捉时序数据中间隔较大的依赖关系。
# * 重置门有助于捕捉时序数据中短期的依赖关系。
# * 更新门有助于捕捉时序数据中长期的依赖关系。
#
#
# ## 练习
#
# * 调调参数（例如数据集大小、序列长度、隐含状态长度和学习率），看看对运行时间、perplexity和预测的结果造成的影响。
# * 在相同条件下，比较门控循环单元和循环神经网络的运行效率。
#
# **吐槽和讨论欢迎点**[这里](https://discuss.gluon.ai/t/topic/4042)
